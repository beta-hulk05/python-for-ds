# %% [markdown]
# Matplotlib

# %%
pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (3.10.3)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (2.3.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\bit\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Data = {'Year': [1920,1930,1940,1950,1960,1970,1980,1990,2000,2010,2020],
        'Exchange Rate': [65,69,71,64,62,59,72,71,75,78,81] }

# %%
## type(Data)

# %%
print(Data)
# Out:
# {'Year': [1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020], 'Exchange Rate': [65, 69, 71, 64, 62, 59, 72, 71, 75, 78, 81]}

# %%
df = pd.DataFrame(Data, columns = ['Year', 'Exchange Rate'] )

# %%
df
# Out:
#     Year  Exchange Rate
# 0   1920             65
# 1   1930             69
# 2   1940             71
# 3   1950             64
# 4   1960             62
# 5   1970             59
# 6   1980             72
# 7   1990             71
# 8   2000             75
# 9   2010             78
# 10  2020             81

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.plot(x = 'Year', y = 'Exchange Rate', kind='line')
plt.show()

# %%
df.plot(x = 'Year', y = 'Exchange Rate', kind='barh')
plt.show()

# %%
df.plot(x = 'Year', y = 'Exchange Rate', kind='scatter')
plt.show()

# %%
df.plot(x = 'Year', y = 'Exchange Rate', kind='bar')
plt.show()

# %%
df.plot(x = 'Year', y = 'Exchange Rate', kind='area')
plt.show()

# %%
plt.scatter(df['Year'], df['Exchange Rate'])
plt.show()

# %% [markdown]
# ## pie charts

# %%
data = {'Tasks': [100,500,300]}
df = pd.DataFrame(data, columns = ['Tasks'], index = ['Pending', 'Completed', 'Ongoing'])
df.plot.pie(y = 'Tasks', figsize = (5,5))
# Out:
# <Axes: ylabel='Tasks'>

# %%
df
# Out:
#            Tasks
# Pending      100
# Completed    500
# Ongoing      300

# %%
churn_df= pd.read_csv('Churn_Modelling.csv')

# %%
churn_df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
churn_df.tail(5)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %%
churn_df.Geography.value_counts().plot(kind = 'barh')
# Out:
# <Axes: ylabel='Geography'>

# %%
(churn_df['Exited'].value_counts()/len(churn_df)*100).plot(kind='bar')
# Out:
# <Axes: xlabel='Exited'>

# %%
plt.bar(churn_df['Geography'], churn_df['EstimatedSalary'].mean(), color = 'red', edgecolor='black')
plt.title('Geography vs Estimated salary')
plt.show()
