# %% [markdown]
# ### Pandas

# %%
pip install pandas
# Out:
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/11.3 MB ? eta -:--:--
#    -- ------------------------------------- 0.8/11.3 MB 2.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.3 MB 2.8 MB/s eta 0:00:04
#    --- ------------------------------------ 1.0/11.3 MB 2.8 MB/s eta 0:00:04
#    ---- ----------------------------------- 1.3/11.3 MB 1.2 MB/s eta 0:00:09
#    ---- ----------------------------------- 1.3/11.3 MB 1.2 MB/s eta 0:00:09
#    ----- ---------------------------------- 1.6/11.3 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.3 MB 1.1 MB/s eta 0:00:09
#    ------ --------------------------------- 1.8/11.3 MB 1.1 MB/s eta 0:00:09
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Churn_Modelling.csv') ## df = data frame
#df = pd.read_excel('xyz.xlsx, sheet_name = 'Page1')

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(5) ### top 5 records . if not mention any number, by default it takes 5
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# ...

# %%
df.tail(10)
# Out:
#       RowNumber  CustomerId      Surname  CreditScore Geography  Gender  Age  \
# 9990       9991    15798964   Nkemakonam          714   Germany    Male   33
# 9991       9992    15769959  Ajuluchukwu          597    France  Female   53
# 9992       9993    15657105  Chukwualuka          726     Spain    Male   36
# 9993       9994    15569266       Rahman          644    France    Male   28
# 9994       9995    15719294         Wood          800    France  Female   29
# 9995       9996    15606229     Obijiaku          771    France    Male   39
# 9996       9997    15569892    Johnstone          516    France    Male   35
# 9997       9998    15584532          Liu          709    France  Female   36
# 9998       9999    15682355    Sabbatini          772   Germany    Male   42
# 9999      10000    15628319       Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info() ## shows info about our dataframe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
## describe:- the statistical information of the numerical columns
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
df.columns ## print all the column names of df
# Out:
# Index(['RowNumber', 'CustomerId', 'Surname', 'CreditScore', 'Geography',
#        'Gender', 'Age', 'Tenure', 'Balance', 'NumOfProducts', 'HasCrCard',
#        'IsActiveMember', 'EstimatedSalary', 'Exited'],
#       dtype='object')

# %%
df.T ## transpose
# Out:
#                       0          1          2         3          4     \
# RowNumber                1          2          3         4          5
# CustomerId        15634602   15647311   15619304  15701354   15737888
# Surname           Hargrave       Hill       Onio      Boni   Mitchell
# CreditScore            619        608        502       699        850
# Geography           France      Spain     France    France      Spain
# Gender              Female     Female     Female    Female     Female
# Age                     42         41         42        39         43
# Tenure                   2          1          8         1          2
# Balance                0.0   83807.86   159660.8       0.0  125510.82
# NumOfProducts            1          1          3         2          1
# HasCrCard                1          0          1         0          1
# IsActiveMember           1          1          0         0          1
# ...

# %%
##sort your data based on age
new_df=df.sort_values("Age")

# %%
new_df.head(5)
# Out:
#       RowNumber  CustomerId          Surname  CreditScore Geography  Gender  \
# 1678       1679    15569178        Kharlamov          570    France  Female
# 4556       4557    15796231          Nwankwo          681    France  Female
# 9520       9521    15673180      Onyekaozulu          727   Germany  Female
# 9526       9527    15665521  Chiazagomekpele          642   Germany    Male
# 9572       9573    15641688          Collier          644     Spain    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 1678   18       4   82767.42              1          1               0
# 4556   18       1   98894.39              1          1               1
# 9520   18       2   93816.70              2          1               0
# 9526   18       5  111183.53              2          0               1
# 9572   18       7       0.00              1          0               1
#
#       EstimatedSalary  Exited
# 1678         71811.90       0
# ...

# %%
df['Balance'] ## want to print column
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df.Balance + 1000
# Out:
# 0         1000.00
# 1        84807.86
# 2       160660.80
# 3         1000.00
# 4       126510.82
#           ...
# 9995      1000.00
# 9996     58369.61
# 9997      1000.00
# 9998     76075.31
# 9999    131142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['New Balance'] = df['Balance'] + 1000 ### creating a new column in our data frame

# %%
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.head(5)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited  New Balance
# 0        101348.88       1      1000.00
# 1        112542.58       0     84807.86
# ...

# %%
df['Random Column'] = 'Good Day'

# %%
## how to access rows & columns
df[20:26]
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 20         21    15577657   McDonald          732    France    Male   41
# 21         22    15597945   Dellucci          636     Spain  Female   32
# 22         23    15699309  Gerasimov          510     Spain  Female   38
# 23         24    15725737     Mosman          669    France    Male   46
# 24         25    15625047        Yen          846    France  Female   38
# 25         26    15738191    Maclean          577    France    Male   25
#
#     Tenure  Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 20       8      0.0              2          1               1
# 21       8      0.0              2          1               0
# 22       4      0.0              1          1               0
# 23       3      0.0              2          0               1
# 24       5      0.0              1          1               1
# 25       3      0.0              2          0               1
#
# ...

# %%
age_50 = df[df.Age > 50]

# %%
len(age_50)
# Out:
# 1261

# %%
len(df)
# Out:
# 10000

# %%
### filling null values
df['Age'].fillna(15)
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %% [markdown]
# Remove columns

# %%
new_df.pop('RowNumber')
# Out:
# 1678    1679
# 4556    4557
# 9520    9521
# 9526    9527
# 9572    9573
#         ...
# 3531    3532
# 3033    3034
# 2458    2459
# 6443    6444
# 6759    6760
# Name: RowNumber, Length: 10000, dtype: int64

# %%
new_df
# Out:
#       CustomerId          Surname  CreditScore Geography  Gender  Age  Tenure  \
# 1678    15569178        Kharlamov          570    France  Female   18       4
# 4556    15796231          Nwankwo          681    France  Female   18       1
# 9520    15673180      Onyekaozulu          727   Germany  Female   18       2
# 9526    15665521  Chiazagomekpele          642   Germany    Male   18       5
# 9572    15641688          Collier          644     Spain    Male   18       7
# ...          ...              ...          ...       ...     ...  ...     ...
# 3531    15653251           Hickey          408    France  Female   84       8
# 3033    15578006              Yao          787    France  Female   85      10
# 2458    15813303          Rearick          513     Spain    Male   88      10
# 6443    15764927           Rogova          753    France    Male   92       3
# 6759    15660878            T'ien          705    France    Male   92       1
#
# ...

# %%
df.Balance
# Out:
# 0            0.00
# 1        83807.86
# 2       159660.80
# 3            0.00
# 4       125510.82
#           ...
# 9995         0.00
# 9996     57369.61
# 9997         0.00
# 9998     75075.31
# 9999    130142.79
# Name: Balance, Length: 10000, dtype: float64

# %%
df['sqrt_balance'] = df['Balance'].apply(np.sqrt)
# Out:
# 0         0.000000
# 1       289.495872
# 2       399.575775
# 3         0.000000
# 4       354.275063
#            ...
# 9995      0.000000
# 9996    239.519540
# 9997      0.000000
# 9998    273.998741
# 9999    360.753087
# Name: Balance, Length: 10000, dtype: float64

# %%
## droping null values
df['Age'].dropna()
# Out:
# 0       42
# 1       41
# 2       42
# 3       39
# 4       43
#         ..
# 9995    39
# 9996    35
# 9997    36
# 9998    42
# 9999    28
# Name: Age, Length: 10000, dtype: int64

# %% [markdown]
# ### concat & merging

# %%
import pandas as pd

df1 = pd.DataFrame
